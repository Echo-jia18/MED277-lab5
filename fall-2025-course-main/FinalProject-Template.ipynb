# %% [markdown]
# # Final Project — A Comparative Study of GPT-3.5 Performance Across Benchmarks
#
# This notebook presents a structured analysis of GPT-3.5’s performance on multiple evaluation benchmarks.
# Each section includes:
# 1. Full experimental code
# 2. Results
# 3. A brief conclusion explaining how the method influences GPT-3.5’s performance and why.
#
# ---
#
# ## Introduction
#
# Provide a concise overview covering the following points:
#
# - Purpose and motivation of the study
# - Description of the benchmarks used
# - Expected behavior and limitations of GPT-3.5 across different task categories
#
# ---
#
# ## Final Conclusion
#
# In this final section, summarize how the different methods affect GPT-3.5’s performance and indicate which methods are most appropriate for specific tasks or situations.
#
# ---
#
# **Name:**
# **MSU Email:**

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## GPT 3.5

# %% [markdown]
# ### MMLU/highschool geography

# %% [markdown]
# ### MMLU-Pro/philosophy

# %% [markdown]
# ### MMLU-Pro/computer science

# %% [markdown]
# ## GPT-3.5 + ReAct Prompting

# %% [markdown]
# ### MMLU/highschool geography

# %% [markdown]
# ### MMLU-Pro/philosophy

# %% [markdown]
# ### MMLU-Pro/computer science

# %% [markdown]
# ## GPT-3.5 + Tool Calling

# %% [markdown]
# ### MMLU/highschool geography

# %% [markdown]
# ### MMLU-Pro/philosophy

# %% [markdown]
# ### MMLU-Pro/computer science

# %% [markdown]
# ## GPT 3.5 + ReAct Prompting + Tool Calling

# %% [markdown]
# ### MMLU/highschool geography

# %% [markdown]
# ### MMLU-Pro/philosophy

# %% [markdown]
# ### MMLU-Pro/computer science

# %% [markdown]
# ## Final Conclusion
